# %%
import pandas as pd

# %%
data=pd.read_csv("insurance_pre.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data=pd.get_dummies(data,drop_first=True)
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=data[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=data[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param={'criterion':['mse','mae','friedman_mse'],'max_features': ['auto','sqrt','log2'],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    3.3s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.754292050956851

# %%
result=grid.cv_results_
print("R2,Best result combination{}:".format(grid.best_params_))
# Out:
# R2,Best result combination{'criterion': 'mae', 'max_features': 'auto', 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010466      0.000000         0.000000    0.000000e+00
# 1        0.007820      0.002091         0.002336    2.054877e-03
# 2        0.004999      0.000002         0.003336    2.358988e-03
# 3        0.005002      0.000001         0.003335    2.357920e-03
# 4        0.005014      0.000011         0.005005    5.619580e-07
# 5        0.005010      0.000013         0.005002    2.996875e-06
# 6        0.041062      0.012269         0.004336    9.440910e-04
# 7        0.027107      0.001541         0.002101    1.639935e-03
# 8        0.019459      0.001916         0.003668    9.424039e-04
# 9        0.013336      0.002358         0.005003    2.247832e-07
# 10       0.018343      0.002348         0.001667    2.357414e-03
# 11       0.016681      0.002351         0.003332    2.356347e-03
# 12       0.005000      0.000003         0.003335    2.358032e-03
# 13       0.003334      0.002357         0.005002    1.189441e-06
# 14       0.003333      0.002357         0.003335    2.358088e-03
# 15       0.003334      0.002358         0.003334    2.357302e-03
# 16       0.003337      0.002359         0.003334    2.357751e-03
# 17       0.003333      0.002357         0.003334    2.357751e-03
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.533684
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.591768
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.653901
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.373508
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.634014
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.629316
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.633819
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.678559
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.649045
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.580375
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.421850
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.623944
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.548696
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.561763
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.575844
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.600816
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.612303
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.659686
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.700438           0.646227         0.626783        0.069452
# 1            0.645083           0.643392         0.626747        0.024744
# 2            0.616412           0.689766         0.653360        0.029949
# 3            0.555843           0.586536         0.505296        0.094027
# 4            0.485339           0.621344         0.580232        0.067299
# 5            0.527290           0.607754         0.588120        0.043905
# 6            0.632780           0.684762         0.650454        0.024263
# 7            0.685113           0.665685         0.676452        0.008070
# 8            0.432880           0.618631         0.566852        0.095543
# 9            0.690020           0.552184         0.607526        0.059456
# 10           0.635362           0.631187         0.562800        0.099681
# 11           0.679287           0.580997         0.628076        0.040233
# 12           0.702686           0.629232         0.626871        0.062888
# 13           0.587323           0.639244         0.596110        0.032236
# 14           0.659364           0.655115         0.630108        0.038409
# 15           0.611981           0.580217         0.597671        0.013157
# 16           0.677260           0.287633         0.525732        0.170437
# 17           0.586255           0.596101         0.614014        0.032544
#
#     rank_test_score
# 0                 7
# 1                 8
# 2                 2
# 3                18
# 4                14
# 5                13
# 6                 3
# 7                 1
# 8                15
# 9                10
# 10               16
# 11                5
# 12                6
# 13               12
# 14                4
# 15               11
# 16               17
# 17                9

# %%
age=float(input("Age:"))
BMI=float(input("BMI:"))
children=int(input("Children:"))
sex=int(input("Male-1 or Female-0:"))
smoker=int(input("Yes-0 or No-1:"))
# Out:
# Age:45
# BMI:15
# Children:1
# Male-1 or Female-0:1
# Yes-0 or No-1:0

# %%
Future_charge_prediction=grid.predict([[age,BMI,children,sex,smoker]])
Future_charge_prediction
print("Future Prediction:{}".format(Future_charge_prediction))
# Out:
# Future Prediction:[48673.5588]
